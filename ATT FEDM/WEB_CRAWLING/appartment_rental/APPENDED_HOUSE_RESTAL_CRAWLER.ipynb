# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#my property

# df1 = pd.read_csv('myproperty-03-05-23.csv');
# df2 = pd.read_csv('myproperty-03-08-23.csv');
# df3 = pd.read_csv('myproperty-03-09-23.csv');
# df4 = pd.read_csv('myproperty-03-10-23.csv');
# df5 = pd.read_csv('myproperty-03-11-23.csv');
# df6 = pd.read_csv('myproperty-03-17-23.csv');
# df7 = pd.read_csv('myproperty-03-18-23.csv');

# %%
#lamudi

# df1 = pd.read_csv('lamudi-03-03-23.csv');
# df2 = pd.read_csv('lamudi-03-04-23.csv');
# df3 = pd.read_csv('lamudi-03-05-23.csv');
# df4 = pd.read_csv('lamudi-03-08-23.csv');
# df5 = pd.read_csv('lamudi-03-09-23.csv');
# df6 = pd.read_csv('lamudi-03-10-23.csv');
# df7 = pd.read_csv('lamudi-03-11-23.csv');
# df8 = pd.read_csv('lamudi-03-17-23.csv');
# df9 = pd.read_csv('lamudi-03-18-23.csv');

# %%
# dotproperty

df1 = pd.read_csv('dotproperty-03-04-23.csv');
df2 = pd.read_csv('dotproperty-03-05-23.csv');
df3 = pd.read_csv('dotproperty-03-08-23.csv');
df4 = pd.read_csv('dotproperty-03-09-23.csv');
df5 = pd.read_csv('dotproperty-03-11-23.csv');
df6 = pd.read_csv('dotproperty-03-17-23.csv');

# %%
# dfs = [df1,df2,df3,df4,df5,df6,df7]
# to_append = ['df2','df3','df4','df5','df6','df7']

# %%
# print(len(to_append))

# %%
df_new = df1.copy()

# %%
# for x in to_append:
#     df_new.append(x)

# %%
df_new.append(df2,ignore_index = True)
# Out:
# C:\Users\win10\AppData\Local\Temp\ipykernel_9028\24348522.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new.append(df2,ignore_index = True)
#       Unnamed: 0                                               name  \
# 0              0  2-Bedroom Furnished Apartment for Rent in Bana...
# 1              1  Very Affordable Semi Furnished Apartment for r...
# 2              2  Affordable Semi Furnished Apartment for rent i...
# 3              3  2- Bedroom Apartment with Own Gate and Garage ...
# 4              4  Most Affordable 2 Bedroom Apartment for rent i...
# ...          ...                                                ...
# 1820         920  LADY BEDSPACE FOR RENT IN AFPOVAI, FORT BONIFA...
# 1821         921  Residential/Commercial Building for Lease at S...
# 1822         922  MACTAN LAPU-LAPU BOUGAINVILLEA Apartment 23 FO...
# 1823         923  1-Bedroom Semi-Furnished Apartment in Banawa, ...
# 1824         924  For Lease: Brand New Staff House/Condo Bldg 6 ...
#
#                                                location  \
# 0     Cebu City\n                                   ...
# 1     Cebu City\n                                   ...
# 2     Cebu City\n                                   ...
# 3     Angeles\n                                    ,...
# 4     Cebu City\n                                   ...
# ...                                                 ...
# 1820  Taguig\n                                    , ...
# 1821  Mandaluyong\n                                 ...
# 1822  Lapu-Lapu\n                                   ...
# 1823  Cebu City\n                                   ...
# 1824  Makati\n                                    , ...
#
#                                                    desc  \
# 0     Property Type: Apartment for RentLocation: Ban...
# 1     Location: Banawa Cebu CityVery Affordable Semi...
# 2     Location: Banawa Cebu CityAffordable Semi Furn...
# 3     Rent/ Month: Php 35,000Details:90 sqm more or ...
# 4     Location: Banawa Cebu City2 Bedroom Apartment ...
# ...                                                 ...
# 1820  LADY BEDSPACE FOR RENT IN AFPOVAI, FORT BONIFA...
# 1821  Residential Building for Lease in Mandaluyong ...
# 1822  For Rent furnished 25 sqm studio type Bougainv...
# 1823  Property Type: Apartment for RentLocation: nea...
# 1824  For Lease: Brand New Staff House/Condo Bldg 6 ...
#
#                                     accomodation  \
# 0      ['<i class="icon icon-bedroom"></i> : 2']
# 1      ['<i class="icon icon-bedroom"></i> : 1']
# 2      ['<i class="icon icon-bedroom"></i> : 1']
# 3      ['<i class="icon icon-bedroom"></i> : 2']
# 4      ['<i class="icon icon-bedroom"></i> : 2']
# ...                                          ...
# 1820   ['<i class="icon icon-bedroom"></i> : 5']
# 1821  ['<i class="icon icon-bedroom"></i> : 43']
# 1822   ['<i class="icon icon-bedroom"></i> : 1']
# 1823   ['<i class="icon icon-bedroom"></i> : 1']
# 1824  ['<i class="icon icon-bedroom"></i> : 44']
#
#                               price
# 0     ₱ 35,000 / month\nNew listing
# 1     ₱ 12,000 / month\nNew listing
# 2     ₱ 12,000 / month\nNew listing
# 3                  ₱ 35,000 / month
# 4     ₱ 15,000 / month\nNew listing
# ...                             ...
# 1820                ₱ 2,500 / month
# 1821              ₱ 700,000 / month
# 1822               ₱ 10,000 / month
# 1823               ₱ 12,000 / month
# 1824            ₱ 1,500,000 / month
#
# [1825 rows x 6 columns]

# %%
df_new = pd.concat([df1,df2,df3,df4,df5,df6], ignore_index=True)

# %%
df_new
# Out:
#       Unnamed: 0                                               name  \
# 0              0  2-Bedroom Furnished Apartment for Rent in Bana...
# 1              1  Very Affordable Semi Furnished Apartment for r...
# 2              2  Affordable Semi Furnished Apartment for rent i...
# 3              3  2- Bedroom Apartment with Own Gate and Garage ...
# 4              4  Most Affordable 2 Bedroom Apartment for rent i...
# ...          ...                                                ...
# 5445         895  Almanza Uno Apartment Room For Rent in Las Piñ...
# 5446         896  1BR Apartment for Rent at Infina Towers, Quezo...
# 5447         897  Apartment Room For Rent at Almanza Uno Las Piñ...
# 5448         898  LADY BEDSPACE FOR RENT IN AFPOVAI, FORT BONIFA...
# 5449         899  Affordable Room For Rent in Almanza Uno Apartm...
#
#                                                location  \
# 0     Cebu City\n                                   ...
# 1     Cebu City\n                                   ...
# 2     Cebu City\n                                   ...
# 3     Angeles\n                                    ,...
# 4     Cebu City\n                                   ...
# ...                                                 ...
# 5445  Las Piñas\n                                   ...
# 5446  Quezon City\n                                 ...
# 5447  Las Piñas\n                                   ...
# 5448  Taguig\n                                    , ...
# 5449  Las Piñas\n                                   ...
#
#                                                    desc  \
# 0     Property Type: Apartment for RentLocation: Ban...
# 1     Location: Banawa Cebu CityVery Affordable Semi...
# 2     Location: Banawa Cebu CityAffordable Semi Furn...
# 3     Rent/ Month: Php 35,000Details:90 sqm more or ...
# 4     Location: Banawa Cebu City2 Bedroom Apartment ...
# ...                                                 ...
# 5445  Gated compoundCctvWell ventilated 12 sqm room ...
# 5446  1BR Apartment for Rent Infina Towers, Quezon C...
# 5447  Gated compoundCctvWell ventilated 12 sqm room ...
# 5448  LADY BEDSPACE FOR RENT IN AFPOVAI, FORT BONIFA...
# 5449  Gated compoundCctvWell ventilated 12 sqm room ...
#
#                                    accomodation                          price
# 0     ['<i class="icon icon-bedroom"></i> : 2']  ₱ 35,000 / month\nNew listing
# 1     ['<i class="icon icon-bedroom"></i> : 1']  ₱ 12,000 / month\nNew listing
# 2     ['<i class="icon icon-bedroom"></i> : 1']  ₱ 12,000 / month\nNew listing
# 3     ['<i class="icon icon-bedroom"></i> : 2']               ₱ 35,000 / month
# 4     ['<i class="icon icon-bedroom"></i> : 2']  ₱ 15,000 / month\nNew listing
# ...                                         ...                            ...
# 5445  ['<i class="icon icon-bedroom"></i> : 1']                ₱ 5,000 / month
# 5446  ['<i class="icon icon-bedroom"></i> : 1']               ₱ 25,000 / month
# 5447  ['<i class="icon icon-bedroom"></i> : 1']                ₱ 5,000 / month
# 5448  ['<i class="icon icon-bedroom"></i> : 5']                ₱ 2,500 / month
# 5449  ['<i class="icon icon-bedroom"></i> : 1']                ₱ 5,000 / month
#
# [5450 rows x 6 columns]

# %%
df_new.shape
# Out:
# (5450, 6)

# %%
df_new.duplicated().sum()
# Out:
# 1262

# %%
import datetime

today_d =  datetime.datetime.now().strftime('%m-%d-%y')
file_name = 'dfa-overall-as-of-' + today_d + '.csv';
file_name
# Out:
# 'dfa-overall-as-of-03-17-23.csv'

# %%
from pathlib import Path  
filepath = Path(r'C:\Users\win10\Documents\ATT.FEDM\WEB_CRAWLING\appartment_rental\\'+file_name)  
filepath.parent.mkdir(parents=True, exist_ok=True)  
dfa_overall.to_csv(filepath)

# %%
dfa1 =  pd.read_csv('lamudi-as-of-03-17-23.csv');
dfa2 =  pd.read_csv('myproperty-as-of-03-17-23.csv');

# %%
dfa1
# Out:
#        Unnamed: 0.1  Unnamed: 0  \
# 0                 0           0
# 1                 1           1
# 2                 2           2
# 3                 3           3
# 4                 4           4
# ...             ...         ...
# 14095         14095        1615
# 14096         14096        1616
# 14097         14097        1617
# 14098         14098        1618
# 14099         14099        1619
#
#                                                    title  \
# 0      Dormitory Spaces for Rent in Santo Tomas, Bata...
# 1      Apartment Building For Rent Located in Molino,...
# 2      Rush For Lease: 35-Door Staff House Near Circu...
# 3      Discounted Price! For Rent Studio Type Apartme...
# 4      RDC Apartment for Rent located at 1156 (c) que...
# ...                                                  ...
# 14095  Studio Type Rooms for Monthly Rent near SM Mal...
# 14096  Studio Apartment for Rent in Plainview, Mandal...
# 14097  Transient Room For Rent in Milagros Subdivisio...
# 14098  For Rent: Furnished Studio Unit at The Celerio...
# 14099  For Rent Eisen Apartel Mla 200mbps nr SM San L...
#
#                            location  \
# 0      Santa Anastacia, Santo Tomas
# 1                Molino VII, Bacoor
# 2                   Olympia, Makati
# 3                 Maypajo, Caloocan
# 4                 Ugong, Valenzuela
# ...                             ...
# 14095           Baclaran, Parañaque
# 14096        Plainview, Mandaluyong
# 14097               Dalig, Antipolo
# 14098               Tejeros, Makati
# 14099            Santa Cruz, Manila
#
#                                              description  \
# 0      Consuelo Park Residences (CPR) is a dormitory ...
# 1      3 Story Apartment / Condo Building Along Molin...
# 2      Rush For Lease: 35-Door Staff House Near Circu...
# 3      Looking for a new, clean, and affordable apart...
# 4      2 STOREY\n2 BEDROOM\n1 TOILET AND BATH\nRESIDE...
# ...                                                  ...
# 14095  E & H Residences  Rooms for monthly rent Studi...
# 14096        Studio unit, 1 toilet and bath, unfurnished
# 14097  Transient Room For Rent in Antipolo City Rizal...
# 14098  The Celerio is located at 4416 Montojo St., Ba...
# 14099  Rent :  daily, weekly, monthly \nDaily:  1139\...
#
#                          price  \
# 0      Contact agent for price
# 1      Contact agent for price
# 2                    ₱ 950,000
# 3                     ₱ 12,000
# 4                      ₱ 7,000
# ...                        ...
# 14095  Contact agent for price
# 14096                 ₱ 11,000
# 14097                    ₱ 500
# 14098                 ₱ 14,000
# 14099                  ₱ 1,139
#
#                                                 features  \
# 0      ['Bedroom : 1', 'Bath : 1', 'Floor area : 15 m²']
# 1      ['Bedrooms : 40', 'Baths : 40', 'Floor area : ...
# 2      ['Bedrooms : 35', 'Baths : 35', 'Floor area : ...
# 3      ['Bedroom : 1', 'Bath : 1', 'Floor area : 26 m²']
# 4      ['Bedrooms : 2', 'Bath : 1', 'Floor area : 36 ...
# ...                                                  ...
# 14095                        ['Bedroom : 1', 'Bath : 1']
# 14096  ['Bedroom : 1', 'Bath : 1', 'Floor area : 24 m²']
# 14097                       ['Bedroom : 1', 'Baths : 2']
# 14098  ['Bedroom : 1', 'Bath : 1', 'Floor area : 23 m²']
# 14099  ['Bedroom : 1', 'Bath : 1', 'Floor area : 12 m²']
#
#                                agent   agent_membership agent_verified
# 0                         Oasis FPIP  MEMBER SINCE 2019       verified
# 1                      Clement Dizon  MEMBER SINCE 2016       verified
# 2                  Fern Marie Badong  MEMBER SINCE 2017       verified
# 3                       JESSA MARTIN  MEMBER SINCE 2022   not verified
# 4                   ROSALIA CRAUWELS  MEMBER SINCE 2021       verified
# ...                              ...                ...            ...
# 14095                      Chloe Chu  MEMBER SINCE 2019       verified
# 14096           Pinnacle Real Estate  MEMBER SINCE 2014       verified
# 14097               Malay Meisin Tan  MEMBER SINCE 2016       verified
# 14098                   Len Magpusao  MEMBER SINCE 2021       verified
# 14099  Eisenbuilders Eisen Apartelle  MEMBER SINCE 2014       verified
#
# [14100 rows x 10 columns]

# %%
dfa2
# Out:
#        Unnamed: 0.1  Unnamed: 0  \
# 0                 0           0
# 1                 1           1
# 2                 2           2
# 3                 3           3
# 4                 4           4
# ...             ...         ...
# 12325         12325        1765
# 12326         12326        1766
# 12327         12327        1767
# 12328         12328        1768
# 12329         12329        1769
#
#                                                    title  \
# 0      Transient Room For Rent in Milagros Subdivisio...
# 1      Dormitory Spaces for Rent in Santo Tomas, Bata...
# 2                               Beautiful house for sale
# 3      Studio Type Rooms for Monthly Rent near SM Mal...
# 4      2 UNITS FOR RENT APARTMENT IN HERRERA ST. STA ...
# ...                                                  ...
# 12325  Condo Sharing Female Bedspace near JP Morgan S...
# 12326                Transient Room 4 sqm in Quezon City
# 12327                         accepting lady bed spacers
# 12328  Condo Sharing Bedspace 4 Rent Merville Paranaq...
# 12329  2Br 55sqm J&H apartments for rent short or lon...
#
#                            location  \
# 0                   Dalig, Antipolo
# 1      Santa Anastacia, Santo Tomas
# 2          Ilustre, President Roxas
# 3               Baclaran, Parañaque
# 4                            Manila
# ...                             ...
# 12325                        Makati
# 12326      East Kamias, Quezon City
# 12327                       Angeles
# 12328                     Parañaque
# 12329                          Cebu
#
#                                              description  \
# 0      Transient Room For Rent in Antipolo City Rizal...
# 1      Consuelo Park Residences (CPR) is a dormitory ...
# 2                               Beautiful house for sale
# 3      E & H Residences  Rooms for monthly rent Studi...
# 4      We have 2 UNITS available:\n6th Floor -2 bedro...
# ...                                                  ...
# 12325  Condo Sharing Female Bedspace near JP Morgan S...
# 12326  Transient Room in Cubao Quezon City (Daily)\nN...
# 12327  We are accepting lady bed spacers. Perfect for...
# 12328  Condo Sharing / BedspaceWoodsville Viverde Man...
# 12329  J&H ApartmentsFully furnished apartments for s...
#
#                          price  \
# 0                        ₱ 500
# 1      Contact agent for price
# 2                        ₱ 123
# 3      Contact agent for price
# 4                     ₱ 13,000
# ...                        ...
# 12325                  ₱ 4,500
# 12326  Contact agent for price
# 12327                  ₱ 1,500
# 12328                  ₱ 3,900
# 12329                 ₱ 25,000
#
#                                                 features          agent  \
# 0                           ['Bedroom : 1', 'Baths : 2']      Malay Tan
# 1      ['Bedroom : 1', 'Bath : 1', 'Floor area : 15 m²']     Oasis FPIP
# 2      ['Bedroom : 1', 'Bath : 1', 'Floor area : 123 ...   combo5 user5
# 3                            ['Bedroom : 1', 'Bath : 1']      Chloe Chu
# 4      ['Bedrooms : 2', 'Baths : 2', 'Floor area : 63...       Eva Choi
# ...                                                  ...            ...
# 12325              ['Bedroom : 1', 'Floor area : 18 m²']  condo sharing
# 12326   ['Bedroom : 1', 'Bath : 1', 'Floor area : 4 m²']     Berry Nula
# 12327                                    ['Bedroom : 1']   LINO SANCHEZ
# 12328              ['Bedroom : 1', 'Floor area : 60 m²']    Rodel Bulan
# 12329  ['Bedrooms : 2', 'Bath : 1', 'Floor area : 55 ...       Hilda NA
#
#         agent_membership agent_verified
# 0      MEMBER SINCE 2021   not verified
# 1      MEMBER SINCE 2019       verified
# 2      MEMBER SINCE 2023   not verified
# 3      MEMBER SINCE 2019       verified
# 4      MEMBER SINCE 2022   not verified
# ...                  ...            ...
# 12325  MEMBER SINCE 2016       verified
# 12326  MEMBER SINCE 2015   not verified
# 12327  MEMBER SINCE 2016       verified
# 12328  MEMBER SINCE 2016       verified
# 12329  MEMBER SINCE 2012   not verified
#
# [12330 rows x 10 columns]

# %%
dfa_overall =pd.concat([dfa1,dfa2])

# %%
dfa_overall.drop(['Unnamed: 0.1','Unnamed: 0'], axis=1, inplace=True)

# %%
dfa_overall.to_csv(filepath)

# %%
dfa_overall.isna().sum()
# Out:
# title               0
# location            0
# description         0
# price               0
# features            0
# agent               0
# agent_membership    0
# agent_verified      0
# dtype: int64

# %%
dfa_overall.dtypes
# Out:
# title               object
# location            object
# description         object
# price               object
# features            object
# agent               object
# agent_membership    object
# agent_verified      object
# dtype: object

# %%
dfa_overall.duplicated().sum()
# Out:
# 26355

# %%
dfa_overall.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9028\854410916.py in <module>
# ----> 1 dfa_overall.dropduplicate()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dropduplicate'
