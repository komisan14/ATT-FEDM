# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## DATA EXPLORATION

# %%
df = pd.read_csv('myproperty as of 03.11.23.csv');

# %%
df.head()
# Out:
#                                                title  \
# 0  Transient Room For Rent in Milagros Subdivisio...
# 1  Dormitory Spaces for Rent in Santo Tomas, Bata...
# 2                           Beautiful house for sale
# 3  Studio Type Rooms for Monthly Rent near SM Mal...
# 4  2 UNITS FOR RENT APARTMENT IN HERRERA ST. STA ...
#
#                        location  \
# 0               Dalig, Antipolo
# 1  Santa Anastacia, Santo Tomas
# 2      Ilustre, President Roxas
# 3          Baclaran, ParaÃ±aque
# 4                        Manila
#
#                                          description                    price  \
# 0  Transient Room For Rent in Antipolo City Rizal...                  â‚± 500
# 1  Consuelo Park Residences (CPR) is a dormitory ...  Contact agent for price
# 2                           Beautiful house for sale                  â‚± 123
# 3  E & H Residences  Rooms for monthly rent Studi...  Contact agent for price
# ...

# %%
df.shape
# Out:
# (151, 10)

# %%
df.duplicated().sum()
# Out:
# 8639

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head(50)
# Out:
#                                                   title  \
# 0     Transient Room For Rent in Milagros Subdivisio...
# 1     Dormitory Spaces for Rent in Santo Tomas, Bata...
# 2                              Beautiful house for sale
# 3     Studio Type Rooms for Monthly Rent near SM Mal...
# 4     2 UNITS FOR RENT APARTMENT IN HERRERA ST. STA ...
# 5                       Urban Pad - Dormitory for Lease
# 6     Discounted Price! For Rent Studio Type Apartme...
# 7     1 Bedroom Apartment on the 2nd Floor with a Bi...
# 8     55sqm 1 bedroom Furnished Apartment for rent i...
# 9     Studio Condo Apartment Bldg. For Rent adjacent...
# 10    1-BR Apartment for Rent at Ferros Bel Air Towe...
# 11                 Bedspace with aircon for rent 25 sqm
# 12    Ladies Bedspace 1 Year Contract Near Mendiola ...
# 13    2 Bedroom Furnished Apartment For Rent in Mand...
# 14    Apartment for rent in Mabolo Cebu City with 4 ...
# 15    Fully Furnished Apartment for Rent in Banilad ...
# ...

# %%
df.isna().sum()
# Out:
# title               0
# location            0
# description         0
# price               0
# features            0
# agent               0
# agent_membership    0
# agent_verified      0
# source              0
# Unnamed: 9          0
# dtype: int64

# %%
//df.unique()
# Out:
#   Input In [10]
#     //df.unique()
#     ^
# SyntaxError: invalid syntax

# %%
df2 = pd.read_csv('myproperty-03-05-23.csv');

# %%
df2.head()

# %%
df2.duplicated().sum()
