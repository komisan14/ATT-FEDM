# %%
import numpy as np;
import pandas as pd;
import seaborn as sns;
import matplotlib.pyplot as plt;

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('house_rental.csv');

# %%
df.head(50)
# Out:
#     Unnamed: 0                                              title  \
# 0            0  Dormitory Spaces for Rent in Santo Tomas, Bata...
# 1            1  Rush For Lease: 35-Door Staff House Near Circu...
# 2            2  Room for Rent in Greenpark Mangahan Pasig near...
# 3            3  Discounted Price! For Rent Studio Type Apartme...
# 4            4  Apartment Building For Rent Located in Molino,...
# 5            5    5 Bedroom Townhouse For Rent in Muntinlupa City
# 6            6  Fully Furnished Apartment for Rent in Binictic...
# 7            7  2 Bedrooms Apartment For Rent in Sisiman, Mari...
# 8            8  Newly Built, Own Meter of Electricity and Wate...
# 9            9                8 Door Brand New Apartment For Rent
# 10          10  For Lease Studio type with loft balut Tondo, M...
# 11          11  RDC Apartment for Rent located at 1156 (c) que...
# 12          12  Apartment for Rent near Cebu Business Park, IT...
# 13          13           apartment / house to let in cordova Cebu
# 14          14  For Rent Corporate/OJT Housing, Room Available...
# 15          15  1 Bedroom Apartment on the 2nd Floor with a Bi...
# 16          16               Apartment For Rent in Lapu-lapu City
# 17          17  Studio Condo Apartment Bldg. For Rent adjacent...
# 18          18  One Bedroom Unit For Rent Fully Furnished Shaw...
# 19          19                    Urban Pad - Dormitory for Lease
# 20          20  Studio Apartment for Rent in Brgy. Plainview, ...
# 21          21  Female Bedspace 1-Bedroom Condo for rent in Pi...
# 22          22  Very Large Convenient 45sqm 1BR Apartment unit...
# 23          23  1 bedroom apartment unit for rent in Dau, Maba...
# 24          24  Bedspace/Private Room for Students / Professio...
# 25          25  Studio Type Rooms for Monthly Rent near SM Mal...
# 26          26  Studio Apartment for Rent in Plainview, Mandal...
# 27          27  Transient Room For Rent in Milagros Subdivisio...
# 28          28  For Rent: Furnished Studio Unit at The Celerio...
# 29          29  For Rent Eisen Apartel Mla 200mbps nr SM San L...
# 30          31  1-BR Apartment for Rent at Ferros Bel Air Towe...
# 31          32  Staff House or Office Space near CIRCUIT Mall ...
# 32          33  2 bedroom apartment for rent in executive subd...
# 33          34  Studio Room for Rent in Tejeros, Makati Conven...
# 34          35  Safestay Apartment for rent at Mactan Airport,...
# 35          36  12 Bedroom Condo for Rent in Makati, Metro Manila
# 36          37  9 Bedroom Condo for Rent in Bangkal, Metro Man...
# 37          38  Php 7,500/month across University of San Carlo...
# 38          39  Apartment for RENT Upper Cubi, Subic Bay Freep...
# 39          40  Room For Rent with CR and Aircon downtown Cebu...
# 40          41  P7,500 Fully Furnished Room With Private Cr Wa...
# 41          42  Php 8,500/month semi furnished w/ windows & pr...
# 42          43  Room For Rent Located In Cebu City Beside Usc ...
# 43          44  Apartment for RENT Forest Hill Subic Bay Freep...
# 44          45  Fully Furnished Room For Rent in Cebu City Cle...
# 45          46  Clean Affordable, Private Cr & Free Wifi Locat...
# 46          47  Fully Furnished Room for Rent Cebu City w/ Pri...
# 47          48  For Rent 1 Bedroom Unit in Milano Residences (...
# 48          49  4 Storey Villa with 9 Rooms Suits for Staff Ho...
# 49          50  Newly Built Apartment unit For Rent in Valenci...
#
#        Municipality      Province  price  \
# 0   Santa Anastacia   Santo Tomas  12500
# 1           Olympia        Makati  54500
# 2        Green Park         Pasig   8500
# 3           Maypajo      Caloocan  12000
# 4        Molino VII        Bacoor  12500
# 5            Cupang    Muntinlupa  54500
# 6            Asinan      Olongapo  24000
# 7           Sisiman     Mariveles  15000
# 8         Molino II        Bacoor   5000
# 9         Molino II        Bacoor   6000
# 10            Tondo        Manila   5000
# 11            Ugong    Valenzuela   7000
# 12           Mabolo          Cebu  10000
# 13           Day-As       Cordova  18500
# 14          Rosario         Pasig  12500
# 15       Banaybanay       Cabuyao   6500
# 16           Gun-Ob     Lapu-Lapu   8500
# 17          Alabang    Muntinlupa   7500
# 18   Addition Hills   Mandaluyong  17000
# 19    Highway Hills   Mandaluyong   5000
# 20        Plainview   Mandaluyong  10000
# 21    Pio Del Pilar        Makati   5000
# 22       San Rafael         Pasay  14000
# 23              Dau     Mabalacat   6000
# 24       Santa Mesa        Manila   2500
# 25         Baclaran     Parañaque  12500
# 26        Plainview   Mandaluyong  11000
# 27            Dalig      Antipolo    500
# 28          Tejeros        Makati  14000
# 29       Santa Cruz        Manila   1139
# 30        Poblacion        Makati  40000
# 31          Olympia        Makati  54500
# 32        San Roque      Antipolo  15000
# 33          Tejeros        Makati   8000
# 34             Pajo     Lapu-Lapu  18000
# 35          Bangkal        Makati  54500
# 36          Bangkal        Makati  54500
# 37        Kamagayan          Cebu   7500
# 38           Asinan      Olongapo  54500
# 39        Kamagayan          Cebu   7500
# 40        Kamagayan          Cebu   7500
# 41        Kamagayan          Cebu   8500
# 42        Kamagayan          Cebu   7500
# 43           Asinan      Olongapo  45000
# 44        Kamagayan          Cebu   8500
# 45        Kamagayan          Cebu   7500
# 46        Kamagayan          Cebu   8500
# 47        Poblacion        Makati  40000
# 48         Don Galo     Parañaque  54500
# 49  North Poblacion      Valencia  18000
#
#                                                 agent  agent_membership  \
# 0                                          Oasis FPIP              2019
# 1                                   Fern Marie Badong              2017
# 2                                          Ed Mallari              2014
# 3                                        JESSA MARTIN              2022
# 4                                       Clement Dizon              2016
# 5                                       Clement Dizon              2016
# 6                                        Birger Helle              2016
# 7                                     Jezreel Vicente              2014
# 8                                         Carl Borela              2023
# 9                                         Carl Borela              2023
# 10                                      Melanie Lopez              2023
# 11                                   ROSALIA CRAUWELS              2021
# 12                                 Cebu Living Spaces              2020
# 13                                   Thomas Fontanari              2016
# 14                               Urbanspace Co-Living              2021
# 15                                 Julio Cezar Redula              2023
# 16                                    Mcdel Apartelle              2019
# 17                                         Yuchi Chua              2019
# 18                                    Danilo Litonjua              2019
# 19                               CBC LAND MGMT., INC.              2018
# 20                               Pinnacle Real Estate              2014
# 21                                      Precious Xiao              2019
# 22                                      Miguel Blanco              2021
# 23                                    Maricel Soriano              2017
# 24                                       Len Magpusao              2021
# 25                                          Chloe Chu              2019
# 26                               Pinnacle Real Estate              2014
# 27                                   Malay Meisin Tan              2016
# 28                                       Len Magpusao              2021
# 29                      Eisenbuilders Eisen Apartelle              2014
# 30                                    Realus Realtors              2022
# 31                                    teresita de paz              2023
# 32                                           Myra Hap              2023
# 33                                      Francis Torre              2015
# 34                                      Sheryl Dungog              2015
# 35                                           Wysly Fu              2020
# 36                                           Wysly Fu              2020
# 37                                      Jackson Siady              2020
# 38                                Broker Janice Stuka              2023
# 39                                      Jackson Siady              2020
# 40                                      Jackson Siady              2020
# 41                                      Jackson Siady              2020
# 42                                      Jackson Siady              2020
# 43                                Broker Janice Stuka              2023
# 44                                      Jackson Siady              2020
# 45                                      Jackson Siady              2020
# 46                                      Jackson Siady              2020
# 47  INFINITY GROUP INTERNATIONAL REALTY & MANAGEME...              2021
# 48                                   Marjorie Pascual              2022
# 49                                 Monamel Valenzuela              2022
#
#    agent_verified        date  vendor  bedroom  bath  floor_area
# 0        verified  03 19 2023  lamudi        1     1          15
# 1        verified  03 19 2023  lamudi       35    35        1100
# 2        verified  03 19 2023  lamudi        1     1          20
# 3    not verified  03 19 2023  lamudi        1     1          26
# 4        verified  03 19 2023  lamudi       40    40        1700
# 5        verified  03 19 2023  lamudi        5     5         270
# 6    not verified  03 19 2023  lamudi        1     1          36
# 7    not verified  03 19 2023  lamudi        2     1          80
# 8        verified  03 19 2023  lamudi        1     1          18
# 9        verified  03 19 2023  lamudi        8     8          18
# 10       verified  03 19 2023  lamudi        1     1          15
# 11       verified  03 19 2023  lamudi        2     1          36
# 12       verified  03 19 2023  lamudi        1     1          22
# 13   not verified  03 19 2023  lamudi        2     2         150
# 14       verified  03 19 2023  lamudi        1     1           0
# 15   not verified  03 19 2023  lamudi        1     1          47
# 16   not verified  03 19 2023  lamudi        1     1          15
# 17       verified  03 19 2023  lamudi       31     1         950
# 18       verified  03 19 2023  lamudi        1     1          41
# 19   not verified  03 19 2023  lamudi        1     1           0
# 20       verified  03 19 2023  lamudi        1     1          22
# 21       verified  03 19 2023  lamudi        1     2          44
# 22       verified  03 19 2023  lamudi        1     1          45
# 23       verified  03 19 2023  lamudi        1     1          30
# 24       verified  03 19 2023  lamudi       12    16         300
# 25       verified  03 19 2023  lamudi        1     1           0
# 26       verified  03 19 2023  lamudi        1     1          24
# 27       verified  03 19 2023  lamudi        1     2           0
# 28       verified  03 19 2023  lamudi        1     1          23
# 29       verified  03 19 2023  lamudi        1     1          12
# 30       verified  03 19 2023  lamudi        1     1          60
# 31   not verified  03 19 2023  lamudi        6     6         320
# 32   not verified  03 19 2023  lamudi        2     2           0
# 33       verified  03 19 2023  lamudi        1     1          20
# 34       verified  03 19 2023  lamudi        1     1          36
# 35       verified  03 19 2023  lamudi       12     6         256
# 36       verified  03 19 2023  lamudi        9     4         150
# 37       verified  03 19 2023  lamudi        1     1          25
# 38       verified  03 19 2023  lamudi        3     3         217
# 39       verified  03 19 2023  lamudi        1     1          25
# 40       verified  03 19 2023  lamudi        1     1          25
# 41       verified  03 19 2023  lamudi        1     1          25
# 42       verified  03 19 2023  lamudi        1     1          25
# 43       verified  03 19 2023  lamudi        3     2         150
# 44       verified  03 19 2023  lamudi        1     1          25
# 45       verified  03 19 2023  lamudi        1     1          25
# 46       verified  03 19 2023  lamudi        1     1          25
# 47       verified  03 19 2023  lamudi        1     1          33
# 48       verified  03 19 2023  lamudi        8     9           0
# 49       verified  03 19 2023  lamudi        1     1          15

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'title', 'Municipality', 'Province', 'price', 'agent',
#        'agent_membership', 'agent_verified', 'date', 'vendor', 'bedroom',
#        'bath', 'floor_area'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0           int64
# title               object
# Municipality        object
# Province            object
# price                int64
# agent               object
# agent_membership     int64
# agent_verified      object
# date                object
# vendor              object
# bedroom              int64
# bath                 int64
# floor_area           int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13855 entries, 0 to 13854
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        13855 non-null  int64
#  1   title             13852 non-null  object
#  2   Municipality      13855 non-null  object
#  3   Province          11679 non-null  object
#  4   price             13855 non-null  int64
#  5   agent             13855 non-null  object
#  6   agent_membership  13855 non-null  int64
#  7   agent_verified    13855 non-null  object
#  8   date              13855 non-null  object
#  9   vendor            13855 non-null  object
#  10  bedroom           13855 non-null  int64
#  11  bath              13855 non-null  int64
#  12  floor_area        13855 non-null  int64
# dtypes: int64(6), object(7)
# memory usage: 1.4+ MB

# %%
df.shape
# Out:
# (13855, 13)

# %%
df['Municipality'].unique()
# Out:
# array(['Santa Anastacia', 'Olympia', 'Green Park', 'Maypajo',
#        'Molino VII', 'Cupang', 'Asinan', 'Sisiman', 'Molino II', 'Tondo',
#        'Ugong', 'Mabolo', 'Day-As', 'Rosario', 'Banaybanay', 'Gun-Ob',
#        'Alabang', 'Addition Hills', 'Highway Hills', 'Plainview',
#        'Pio Del Pilar', 'San Rafael', 'Dau', 'Santa Mesa', 'Baclaran',
#        'Dalig', 'Tejeros', 'Santa Cruz', 'Poblacion', 'San Roque', 'Pajo',
#        'Bangkal', 'Kamagayan', 'Don Galo', 'North Poblacion',
#        'Pamplona Tres', 'Pembo', 'Don Bosco', 'Sampaloc', 'Camarin',
#        'Lahug', 'Carmen', 'Pinyahan', 'Ermita', 'Cubao', 'Novaliches',
#        'Cutcut', 'Tisa', 'San Isidro', 'Tandang Sora', 'Taguibo',
#        'Angeles', 'Upper Bicutan', 'Santiago', 'Talon Singko', 'Banilad',
#        'Muzon', 'B.F. International Village', 'Ugong Norte', 'Pinagsama',
#        'Kalubkob', 'Malabanias', 'Amsic', 'Clark', 'Sapangbato',
#        'Villa Kananga', 'Mandaluyong', 'Biñan', 'Almanza Dos',
#        'Barangay 34-D', 'Manila', 'Cebu IT Park', 'Palanan',
#        'Salcedo Village', 'Western Bicutan', 'Horseshoe', 'Pandacan',
#        'Mayamot', 'Sen. Gil Puyat Avenue', 'Marcelo Green Village',
#        'Tungkong Mangga', 'Tabok', 'Pampang', 'Bagong Buhay',
#        'Marikina Heights', 'Santa Lucia', 'East Kamias', 'Bel-Air',
#        'Tambo', 'Cansojong', 'Guadalupe', 'Calamba', 'Libaong',
#        'Tubtubon', 'Kauswagan', 'West Rembo', 'San Lorenzo', 'Parañaque',
#        'Sacred Heart', 'Anunas', 'Talamban', 'Tatalon', 'Socorro',
#        'Guadalupe Nuevo', 'Pilar', 'Santo Domingo', 'Balibago', 'La Paz',
#        'San Antonio', 'Culiat', 'Makati', 'Pasay Rotonda', 'Capitol Site',
#        'Dolores', 'Diliman', 'Pallocan Kanluran', 'Marulas', 'Malate',
#        'Tinago', 'La Loma', 'E. Rodriguez', 'Tanzang Luma VI',
#        'San Andres', 'Capaya', 'Talipapa', 'Chino Roces', 'Libertad',
#        'Moonwalk', 'Subangdaku', 'Bagong Pag-Asa', 'Bambang', 'Ususan',
#        'Commonwealth', 'Del Monte', 'Pulantubig', 'Barangay 20-B',
#        'Real II', 'Umapad', 'Dalandanan', 'Taft', 'Santolan', 'Agus',
#        'Sindalan', 'Ambiong', 'Veterans Village', 'Barangay 19-B',
#        'Gov. Paciano Bangoy', 'Tunasan', 'McKinley Hill', 'Onse',
#        'Buenavista II', 'Pineda', 'Alicia', 'Legarda-Burnham-Kisad',
#        'Palingon', 'MOA', 'Manoc-Manoc', 'Villamonte', 'B.F. Homes',
#        'Cabantian', 'Pasong Kawayan II', 'Canduman', 'Legazpi Village',
#        'Salapan', 'San Francisco', 'Bay City', 'Hulo', 'Sasa', 'Tacas',
#        'Santo Cristo', 'Manggahan', 'Talon Tres', 'Rizal', 'San Manuel',
#        'Lodlod', 'San Miguel', 'Barangay 18', 'Dao', 'City Heights',
#        'Labangon', 'Grace Park East', 'Alangilan', 'Cuayan',
#        'Barangay 91', 'Makiling', 'North Avenue', 'Fort Bonifacio',
#        'Jagobiao', 'Camputhaw', 'Buhangin', 'Lamac', 'Pasong Tamo',
#        'Lalangan', 'Davao', 'Maybunga', 'Bantayan', 'Balabag West',
#        'Campetik', 'Dagatan', 'Molino III', 'Putatan', 'Manuyo Dos',
#        'Baesa', 'Guadalupe Viejo', 'Salvacion', 'La Esperanza', 'Booy',
#        'Zapatera', 'Kamuning', 'Cebu', 'Apas', 'Bakakeng Central',
#        'Agapito del Rosario', 'Talon Dos', 'Landayan', 'Kaligayahan',
#        'Manook', 'A-Et', 'Banawa', 'Magugpo East', 'Fairview',
#        'Talon Kuatro', 'Maharlika', 'Quirino 3-A', 'Almanza Uno',
#        'Kaunlaran', 'Laging Handa', 'Project 8', 'Mactan', 'Santa Ana',
#        'F.B Harisson', 'Nazareth', 'Loma de Gato', 'Taclobo',
#        'Sun Valley', 'Comembo', 'East Rembo', 'Apolonio Samson',
#        'Singcang-Airport', 'Alasas', 'Lawaan I', 'Pitogo',
#        'Barangka Ilaya', 'Bagatayam', 'Dumlog', 'Doña Josefa',
#        'Katipunan', 'Catalunan Grande', 'Ermitaño', 'Pildera I',
#        'Bagacay', 'La Mesa', 'Puting Kahoy', 'Matina Crossing',
#        'Lawaan III', 'Vitalez', 'Barihan', 'PNR Compound', 'Ortigas CBD',
#        'San Sebastian', 'Mabiga', 'Aranguren', 'Lower Bicutan',
#        'Project 4', '50th District', 'Ayala Alabang', 'Pakigne',
#        'Kasilawan', 'Malibay', 'Candau-Ay', 'Valencia', 'Pinagkaisahan',
#        'Dugcal', 'San Bartolome', 'Malinta', 'Kalayaan', 'Mauway',
#        'Maguikay', 'Mambaling', 'Lawa', 'Teachers Village West',
#        'Quintin Salas', 'Sagad', 'Basak San Nicolas', 'Cabitoonan',
#        'Cabrera', 'South Triangle', 'Malagasang I-C', 'San Juan',
#        'Old Zañiga', 'Tumaga', 'Pinagbuhatan', 'Antipolo', 'Taculing',
#        'Rincon', 'Alijis', 'Barangay 16', 'Catmon', 'Langkiwa',
#        'Bakakeng North', 'Niog II', 'Bayanan', 'Tabunoc', 'Malamig',
#        'San Martin de Porres', 'Bayabas', 'Sambag II', 'Lara',
#        'J.P. Laurel', 'Punta Princesa', 'Pulang Lupa Dos',
#        'Country Club Village', 'Santa Rosa', 'Bagong Ilog', 'San Pablo',
#        'Linao', 'Malitlit', 'San Nicolas Central', 'Lourdes Sur', 'Looc',
#        'Barangay 18-B', 'Project 6', 'Sambag I', 'Real', 'Tramo',
#        'Duquit', 'Paco', "Cabinet Hill-Teacher's Camp", 'Holy Spirit',
#        'Palao', 'Mambugan', 'Kapitolyo', 'Potrero', 'Don Carlos Village',
#        'San Luis Village', 'Sucat', 'Mankilam', 'Immaculate Concepcion',
#        'San Jose', 'Villa Petrona', 'Baguio', 'Aurora', 'Pildera II',
#        'Quezon City', 'Outlook Drive', 'Camachiles', 'Tagapo', 'Gusa',
#        'Santa Rita Karsada', 'Halang', 'Parian', 'Subabasbas',
#        'Alfonso Angliongto S', 'Estefania', 'Mabini-J. Rizal',
#        'South Cembo', 'Bagong Tanyag', 'Maribago', 'Caniogan', 'Bulihan',
#        'Panginay', 'Dulong Bayan', 'Mines View Park', 'Quiot Pardo',
#        'Bagumbong', 'Camanang', 'Bata', 'Aromahon',
#        'C-3 Road  Kaunlaran Village', 'Tunghaan', 'San Agustin', 'Pajac',
#        'Katuparan', 'Tubuan II', 'Mayondon', 'Babag', 'Palma-Urbano',
#        'Ibayo-Tipas', 'Matina Aplaya', 'Malanday', 'Blue Ridge A',
#        'Nagkaisang Nayon', 'Damayan', 'Bago Aplaya', 'Lapnit',
#        'Canlubang', 'Dalagdag', 'Sienna', 'Bucana', 'Balong Bato',
#        'Poliwes', 'Cebu Business Park', 'Kasambagan', 'Maharlika West',
#        'Wack-Wack Greenhills', 'Carasuchi', 'Balong-Bato', 'Punta Engaño',
#        'Pusok', 'N.S. Amoranto', 'Batasan Hills', 'Lorega',
#        'Santa Filomena', 'Luciente 1.0', 'New Quezon', 'Loyola Heights',
#        'Santo Rosario', 'Ilustre', 'Guizo', 'Bahay Pare', 'Silangan',
#        'San Nicolas', 'Alfonso Tabora', 'Barangka Drive', 'Paltok',
#        'Pari-An', 'Lourdes Sur East', 'Gulod', 'Matica-A',
#        'Aurora Hill Proper', 'Carmona', 'Barangka Itaas', 'Tagpos',
#        'Salaysay', 'Molugan', 'Balbagon', 'Quirino 2-A',
#        'Sungay South-East', 'Canaway', 'Central', 'Panadtaran',
#        'Maharlika Village', 'Greenhills', 'Ampid I', 'Paciano Rizal',
#        'Amihan', 'Quiapo', 'Arellano', 'Tinajeros', 'Doña Imelda',
#        'Langka', 'Cogon Ramos', 'Emmanuel Bergado I', 'Barangay 25-C',
#        'San Vicente', 'Signal Village', 'San Dionisio', 'Aguho', 'Pardo',
#        'Bagumbayan', 'Valenzuela', 'Dila', 'San Carlos', 'Palanas',
#        'Ayala Avenue', 'Villamor Air Base', 'Ortigas Avenue', 'Tangub',
#        'Camaman-An', 'Magliman', 'Don Jose', 'Barangay 14', 'Banaba',
#        'Casuntingan', 'Lumbia', 'Bahay Toro', 'Macasandig', 'New Manila',
#        'Valle Verde 6', 'Sudlon I', 'Santo Niño', 'Pandan', 'Marilag',
#        'Doña Juana', 'Tipolo', 'Dontogan', 'Cembo', 'Teodora Alonzo',
#        'Little Baguio', 'San Roque Village', 'Quirino 2-B', 'New Era',
#        'Asin Road', 'Bagong Silang', 'San Isidro Norte', 'Dagat-Dagatan',
#        'Pasay', 'Mabalacat', 'Pulo', 'Makati Avenue', 'Lagundi',
#        'Paliparan III', "Veteran's Village", 'Paraiso', 'Magallanes',
#        'Hagdang Bato Libis', 'Cainta', 'Boni Avenue', 'Kaylaway',
#        'Batingan', 'Karuhatan', 'Ramon Magsaysay', 'Talon Uno', 'Cebuano',
#        'Langkaan II', 'Calzada', 'Dominican Hill-Mirador', 'Batinguel',
#        'Binlod', 'Marigondon', 'General Luna', 'Bagong Sikat', 'Malusak',
#        'Mandaue', 'Taguig', 'Marikina', 'Caloocan', 'Laoag', 'Lipa',
#        'Panglao', 'Iloilo', 'Tagum', 'Basak Pardo', 'Tanza', 'Talisay',
#        'Kabankalan', 'Las Piñas', 'Pulilan', 'Panabo', 'Lapu-Lapu',
#        'Pasig', 'Malvar', 'Quezon Avenue', 'Silang', 'Dumaguete',
#        'Eastwood City', 'Matina Pangi', 'Daang Sarile', 'Cutcot',
#        'Muntinlupa', 'Newport City', 'West Triangle', 'Prinza', 'Estaca',
#        'Bancao-Bancao', 'Kaytapos', 'Saint Francis', 'Cabuyao', 'Batino',
#        'Balulang', 'Cagayan de Oro', 'Talaan Aplaya', 'Binauganan',
#        'Balayan', 'Bagong Silangan', 'Batangas City', 'Tapuac',
#        'Sangandaan', 'Peñaplata', 'General Trias', 'Milagrosa',
#        'Pasong Putik Proper', 'Liptong', 'Sampaga', 'Tanauan', 'Bulacan',
#        'Barangka', 'Rockwell', 'San Pedro', 'Maslog', 'Subic',
#        'Nayong Kanluran', 'Kaybagal South', 'Tayud', 'Pulong Santa Cruz',
#        'Tagaytay', 'Pawing', 'Deparo', 'Pateros', 'City of San Fernando',
#        'Sabang', 'Roxas', 'Santo Tomas', 'Barangay 26-C', 'Barangay 8-A',
#        'Sampaloc II', 'Danglag', 'Maramag', 'Langkaan I', 'Pittland',
#        'Merville', 'Taloto', 'Bungad', 'White Plains', 'Inosloban',
#        'Project 3', 'Hen. T. de Leon', 'Bacoor', 'Cavite City', 'Lourdes',
#        'Molino V', 'Maricaban', 'Jugan', 'Bolod', 'San Fernando',
#        'Krus Na Ligas', 'Malay', 'Bacolod', 'Maluso', 'Pinagbakahan',
#        'Teachers Village East', 'Valle Verde 5', 'Cogon', 'New Zañiga',
#        'Abangan Norte', 'Catmondaan', 'Barangay 72', 'Nangka', 'Sogod',
#        'Namayan', 'Camantiles', 'Camp 7', 'Bakilid', 'Apolong',
#        'Kanluran', 'Project 7', 'Calawisan', 'Opao',
#        'Bagong Lipunan Ng Crame', 'Maytunas', 'Mariblo', 'Central Manila',
#        'Isawan', 'Santa Teresita', 'Bacungan', 'Basak',
#        'Bgy. 40 - Cruzada', 'Sapang Maisac', 'Lucao', 'Mahabang Parang',
#        'Pacdal', 'Paracale', 'Silago', 'Sulodpan', 'St. Peter',
#        'Pulung Maragul', 'Santa Maria', 'San Isidro Labrador',
#        'Barangay VI', 'Binondo', 'Naic', 'Heroes Del 96'], dtype=object)

# %%
#Replacing the 'contact agent for price' into null values
def change_price(col):
    price_change = 'Contact agent for price';
    
    df[col][df[col] == price_change] = None;

# %%
change_price('price')

# %%
df['price']
# Out:
# 0        12500
# 1        54500
# 2         8500
# 3        12000
# 4        12500
#          ...
# 13850    10500
# 13851     4500
# 13852    45000
# 13853    54500
# 13854    12500
# Name: price, Length: 13855, dtype: int64

# %%
df.drop(['Unnamed: 0','agent', 'title'], axis = 1, inplace=True)

# %%
df.duplicated().sum()
# Out:
# 978

# %%
df = df.drop_duplicates()

# %%
df.isna().sum()
# Out:
# Municipality           0
# Province            1988
# price                  0
# agent_membership       0
# agent_verified         0
# date                   0
# vendor                 0
# bedroom                0
# bath                   0
# floor_area             0
# dtype: int64

# %%
#Change Datatypes into string values
df = df.astype('string')

# %%
df.dtypes
# Out:
# Municipality        string
# Province            string
# price               string
# agent_membership    string
# agent_verified      string
# date                string
# vendor              string
# bedroom             string
# bath                string
# floor_area          string
# dtype: object

# %%
#Parse the price into float data type
df['price'] = df['price'].astype(float)
df['bedroom'] = df['bedroom'].astype(float)
df['floor_area'] = df['floor_area'].astype(float)
df['bath'] = df['bath'].astype(float)

# %%
df.dtypes
# Out:
# Municipality         string
# Province             string
# price               float64
# agent_membership     string
# agent_verified       string
# date                 string
# vendor               string
# bedroom             float64
# bath                float64
# floor_area          float64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)

# %%
df.dtypes
# Out:
# Municipality                string
# Province                    string
# price                      float64
# agent_membership            string
# agent_verified              string
# date                datetime64[ns]
# vendor                      string
# bedroom                    float64
# bath                       float64
# floor_area                 float64
# dtype: object

# %%
# 
for col in df.columns:
    if (col != 'price' and df[col].dtypes == 'float64'):
        plt.figure()
        sns.boxplot(df[col])

# %%
def remove_outliers(col):
    q1 = df[col].quantile(0.25);
    q3 = df[col].quantile(0.75);
    iqr = q3 - q1;
    
    max_ = q3 + (1.5*iqr);
    min_ = q1 - (1.5*iqr);
    
    df[col][df[col] < min_] = min_;
    df[col][df[col] > max_] = max_;

# %%
remove_outliers('price')

# %%
# for col in df.columns:
#     if (col != 'price' and df[col].dtypes == 'float64'):
#         plt.figure()
#         sns.boxplot(df[col])

# %%
for col in df.columns:
    if (col != 'price' and df[col].dtypes == 'float64'):
        remove_outliers(col)

# %%
for col in df.columns:
    if (col != 'price' and df[col].dtypes == 'float64'):
        plt.figure()
        sns.boxplot(df[col])

# %%
df['price'].fillna(df['price'].median(),inplace = True);

# %%
df
# Out:
#           Municipality      Province    price agent_membership agent_verified  \
# 0      Santa Anastacia   Santo Tomas  12500.0             2019       verified
# 1              Olympia        Makati  52450.0             2017       verified
# 2           Green Park         Pasig   8500.0             2014       verified
# 3              Maypajo      Caloocan  12000.0             2022   not verified
# 4           Molino VII        Bacoor  12500.0             2016       verified
# ...                ...           ...      ...              ...            ...
# 13849     Capitol Site          Cebu  25000.0             2016       verified
# 13850       Subangdaku       Mandaue  10500.0             2012       verified
# 13851      Almanza Uno     Las Piñas   4500.0             2019       verified
# 13852           Cuayan       Angeles  45000.0             2022       verified
# 13853           Asinan      Olongapo  52450.0             2023       verified
#
#             date       vendor  bedroom  bath  floor_area
# 0     2023-03-19       lamudi      1.0   1.0        15.0
# 1     2023-03-19       lamudi      3.5   3.5       178.5
# 2     2023-03-19       lamudi      1.0   1.0        20.0
# 3     2023-03-19       lamudi      1.0   1.0        26.0
# 4     2023-03-19       lamudi      3.5   3.5       178.5
# ...          ...          ...      ...   ...         ...
# 13849 2023-03-24  my property      3.0   2.0       100.0
# 13850 2023-03-24  my property      1.0   1.0         0.0
# 13851 2023-03-24  my property      1.0   0.0        18.0
# 13852 2023-03-24  my property      3.0   3.0       120.0
# 13853 2023-03-24  my property      3.0   3.0       178.5
#
# [12877 rows x 10 columns]

# %%
df.dtypes
# Out:
# Municipality                string
# Province                    string
# price                      float64
# agent_membership            string
# agent_verified              string
# date                datetime64[ns]
# vendor                      string
# bedroom                    float64
# bath                       float64
# floor_area                 float64
# dtype: object

# %%
df.shape
# Out:
# (12877, 10)

# %%
df.dtypes
# Out:
# Municipality                string
# Province                    string
# price                      float64
# agent_membership            string
# agent_verified              string
# date                datetime64[ns]
# vendor                      string
# bedroom                    float64
# bath                       float64
# floor_area                 float64
# dtype: object

# %%
# df['bedroom'] = df['bedroom'].astype(float)
# df['floor_area'] = df['floor_area'].astype(float)
# df['bath'] = df['bath'].astype(float)

# %%
df.dtypes
# Out:
# Municipality                string
# Province                    string
# price                      float64
# agent_membership            string
# agent_verified              string
# date                datetime64[ns]
# vendor                      string
# bedroom                    float64
# bath                       float64
# floor_area                 float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Municipality           0
# Province            1988
# price                  0
# agent_membership       0
# agent_verified         0
# date                   0
# vendor                 0
# bedroom                0
# bath                   0
# floor_area             0
# dtype: int64

# %%
df['Province'] = df['Province'].fillna('NA');

# %%
# df['bedroom'] = df['bedroom'].fillna(0);
# df['bath'] = df['bath'].fillna(0);
# df['floor_area'] = df['floor_area'].fillna(0);

# %%
df.isna().sum()
# Out:
# Municipality        0
# Province            0
# price               0
# agent_membership    0
# agent_verified      0
# date                0
# vendor              0
# bedroom             0
# bath                0
# floor_area          0
# dtype: int64

# %%
# from pathlib import Path  
# filepath = Path(r'C:\Users\win10\Documents\ATT FEDM\\project'+'tajee.csv')  
# filepath.parent.mkdir(parents=True, exist_ok=True)  
# df.to_csv(filepath)

# %%
from sklearn.preprocessing import LabelEncoder 

encoder = LabelEncoder()

for col in df.columns:
    if(df[col].dtypes != 'float64'):
        df[col] = encoder.fit_transform(df[col])

# %%
df
# Out:
#        Municipality  Province    price  agent_membership  agent_verified  \
# 0               542       106  12500.0                 9               1
# 1               406        60  52450.0                 7               1
# 2               228        85   8500.0                 4               1
# 3               375        20  12000.0                12               0
# 4               384         6  12500.0                 6               1
# ...             ...       ...      ...               ...             ...
# 13849           150        24  25000.0                 6               1
# 13850           576        67  10500.0                 2               1
# 13851            15        51   4500.0                 9               1
# 13852           175         0  45000.0                12               1
# 13853            30        77  52450.0                13               1
#
#        date  vendor  bedroom  bath  floor_area
# 0         0       0      1.0   1.0        15.0
# 1         0       0      3.5   3.5       178.5
# 2         0       0      1.0   1.0        20.0
# 3         0       0      1.0   1.0        26.0
# 4         0       0      3.5   3.5       178.5
# ...     ...     ...      ...   ...         ...
# 13849     4       1      3.0   2.0       100.0
# 13850     4       1      1.0   1.0         0.0
# 13851     4       1      1.0   0.0        18.0
# 13852     4       1      3.0   3.0       120.0
# 13853     4       1      3.0   3.0       178.5
#
# [12877 rows x 10 columns]

# %%
# from sklearn.preprocessing import MinMaxScaler;

# scaler = MinMaxScaler()
# df_new = df.copy()

# for col in df.columns:
#     if (col != 'price'):
#         df_new[col] = scaler.fit_transform(df_new[col].values.reshape(-1,1))

# %%
df.dtypes
# Out:
# Municipality          int32
# Province              int32
# price               float64
# agent_membership      int32
# agent_verified        int32
# date                  int64
# vendor                int32
# bedroom             float64
# bath                float64
# floor_area          float64
# dtype: object

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
corr = df.corr();
corr_mask = corr.mask(np.triu(np.ones_like(corr, dtype=bool)))
corr_unstacked = corr_mask.unstack().sort_values(ascending = False);
corr_df = pd.DataFrame(corr_unstacked[abs(corr_unstacked)>.75]).sort_index()

# %%
corr_df
# Out:
# Empty DataFrame
# Columns: [0]
# Index: []

# %%
X = df.drop(['price'],axis=1)
y = df['price']

# %%
plt.scatter(y,y)

# %%
from sklearn.model_selection import train_test_split

# %%
# X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42, train_size=.80);

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
def evaluate_model(model, X,y):
    X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42, train_size = .80);
    model.fit(X_train, y_train);
    
    y_pred = model.predict(X_test);
    print('r^2 Score: ', r2_score(y_test, y_pred)) # accuracy score
    print('Mean Absolute Error: ', mean_absolute_error(y_test, y_pred)); #closer to zero, better
    print('Root Mean Square Eror: ', np.sqrt(mean_squared_error(y_test, y_pred)))  #closer to zero, better
    
    plt.scatter(y_train, model.predict(X_train), color='g')
    plt.plot(y_pred, y_pred)
    plt.show()

# %%
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import GradientBoostingRegressor;
from sklearn.linear_model import LinearRegression
from sklearn.kernel_ridge import KernelRidge;
from xgboost import XGBRegressor;
from lightgbm import LGBMRegressor;
from sklearn.ensemble import RandomForestRegressor

# %%
models = [BayesianRidge(),SGDRegressor(),ElasticNet(),GradientBoostingRegressor()
          ,LinearRegression(),KernelRidge(),XGBRegressor(),LGBMRegressor(), RandomForestRegressor()]
for model in models:
    print(model)
    evaluate_model(model, X,y)
# Out:
# BayesianRidge()
# r^2 Score:  0.48748821812156684
# Mean Absolute Error:  8376.408886173067
# Root Mean Square Eror:  11442.551085494582
# SGDRegressor()
# r^2 Score:  -4.627882875892224e+17
# Mean Absolute Error:  10097031945064.67
# Root Mean Square Eror:  10873318581521.256
# ElasticNet()
# r^2 Score:  0.4693451013113279
# Mean Absolute Error:  8549.790483275092
# Root Mean Square Eror:  11643.325053309925
# GradientBoostingRegressor()
# r^2 Score:  0.668902313041323
# Mean Absolute Error:  6575.615907530147
# Root Mean Square Eror:  9197.059721507509
# LinearRegression()
# r^2 Score:  0.48739620950105866
# Mean Absolute Error:  8377.351407508322
# Root Mean Square Eror:  11443.578150754724
# KernelRidge()
# r^2 Score:  0.48790560257260884
# Mean Absolute Error:  8430.77927516262
# Root Mean Square Eror:  11437.89078709913
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# r^2 Score:  0.9435178148639835
# Mean Absolute Error:  2553.761539174903
# Root Mean Square Eror:  3798.6272396392146
# LGBMRegressor()
# r^2 Score:  0.8382153523015391
# Mean Absolute Error:  4475.605830285869
# Root Mean Square Eror:  6428.943173484271
# RandomForestRegressor()
# r^2 Score:  0.9658971562518956
# Mean Absolute Error:  1273.964258386541
# Root Mean Square Eror:  2951.659326504712

# %%
rf = RandomForestRegressor()
# rf.fit(X_train, y_train)
evaluate_model(rf, X,y)

plt.plot(rf.feature_importances_)
# Out:
# r^2 Score:  0.9659380326109976
# Mean Absolute Error:  1268.455552525998
# Root Mean Square Eror:  2949.8898367891265

# %%
X.columns
# Out:
# Index(['Municipality', 'Province', 'agent_membership', 'agent_verified',
#        'date', 'vendor', 'bedroom', 'bath', 'floor_area'],
#       dtype='object')

# %% [markdown]
# ### FEATURE ENGINEERING TECHNIQUES

# %%
#information gain
from sklearn.feature_selection import mutual_info_classif
import matplotlib.pyplot as plt
# %matplotlib inline

importances = mutual_info_classif(X,y);
feat_importances = pd.Series(importances, df.columns[0:len(df.columns)-1])
feat_importances.plot(kind='barh', color='teal')
plt.show()

# %%
X_ig = X.drop(['agent_verified'], axis=1)

# %%
evaluate_model(rf,X_ig,y)
# Out:
# r^2 Score:  0.9542324808289911
# Mean Absolute Error:  1448.3263266220774
# Root Mean Square Eror:  3419.397731773625

# %%
#Chi square test
from sklearn.feature_selection import SelectKBest;
from sklearn.feature_selection import chi2;

chi2_features = SelectKBest(chi2, k = 4); # k is the number of features you want to retain
X_chi2 = chi2_features.fit_transform(X,y);

evaluate_model(rf,X_chi2,y)
# Out:
# r^2 Score:  0.9178083928678759
# Mean Absolute Error:  1737.900791664986
# Root Mean Square Eror:  4582.3121413797135

# %%
#Correlation
corr = df.corr()
corr['price'] = abs(corr['price'])
corr['price']
# Out:
# Municipality        0.126688
# Province            0.077148
# price               1.000000
# agent_membership    0.110193
# agent_verified      0.185244
# date                0.001041
# vendor              0.014566
# bedroom             0.561857
# bath                0.475513
# floor_area          0.617503
# Name: price, dtype: float64

# %%
#calculate MAD
mean_abs_diff = np.sum(np.abs(X - np.mean(X,axis = 0)),axis = 0)/X.shape[0];
plt.bar(np.arange(X.shape[1]),mean_abs_diff, color = 'teal')
# Out:
# <BarContainer object of 9 artists>

# %%
X.columns
# Out:
# Index(['Municipality', 'Province', 'agent_membership', 'agent_verified',
#        'date', 'vendor', 'bedroom', 'bath', 'floor_area'],
#       dtype='object')

# %%
from sklearn.model_selection import cross_val_score

from sklearn.decomposition import PCA

pca = PCA(n_components= 3)
X_pca = pca.fit_transform(X)
pca_df = pd.DataFrame(data = X_pca,columns = ['PCA1','PCA2','PCA3'])

evaluate_model(rf,pca_df,y)
# print(cross_val_score(rf,pca_df,y,cv = 10).mean())
# Out:
# r^2 Score:  0.9560006319190838
# Mean Absolute Error:  1257.9056334967438
# Root Mean Square Eror:  3352.6958186083534

# %%
fig = plt.figure();
ax = fig.add_subplot(projection = '3d');

ax.scatter(pca_df ['PCA1'],pca_df ['PCA2'],pca_df ['PCA3'],
          c = y, marker = 'o')

# %%
from sklearn.decomposition import FastICA

ica = FastICA(n_components = 3)
X_ica = ica.fit_transform(X)

evaluate_model(rf,X_ica,y)
# print(cross_val_score(rf,X_ica,y,cv = 10).mean())
# Out:
# r^2 Score:  0.955489443190147
# Mean Absolute Error:  1238.0936914538222
# Root Mean Square Eror:  3372.115541555318

# %%
ica_df = pd.DataFrame(data = X_ica,columns = ['ICA1','ICA2','ICA3'])

fig = plt.figure();
ax = fig.add_subplot(projection = '3d');

ax.scatter(ica_df ['ICA1'],ica_df ['ICA2'],ica_df ['ICA3'],
          c = y, marker = 'o')

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis;

lda = LinearDiscriminantAnalysis(n_components = 4)

X_lda = lda.fit(X,y).transform(X)
evaluate_model(rf,X_lda,y)
# print(cross_val_score(rf,X_lda,y,cv = 10).mean())
# Out:
# r^2 Score:  0.9420406313176856
# Mean Absolute Error:  1966.7386103504632
# Root Mean Square Eror:  3847.97955920478

# %%
# from sklearn.manifold import LocallyLinearEmbedding

# embedding = LocallyLinearEmbedding(n_components = 4)
# x_lle = embedding.fit_transform(X)

# evaluate_model(rf, x_lle, y)
# print(cross_val_score(rf,x_lle,y,cv=10).mean())

# %%
# fig, ax = plt.subplots(figsize=(10, 6))
# ax.scatter(x_lle[:, 0], x_lle[:, 1], c='teal', cmap=plt.cm.Spectral)
# ax.set_title("Locally Linear Embedding")
# plt.show()
